# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
analysis_k1 = pd.read_excel("FCSdaten/20181030-141038_eGFP_20180904_K1_K1.xlsx",sheet_name="GFP_params")
analysis_k2 = pd.read_excel("FCSdaten/20181030-141040_eGFP_20180904_K2_K2.xlsx",sheet_name="GFP_params")
analysis_k3 = pd.read_excel("FCSdaten/20181030-141041_eGFP_20180904_K3_K3.xlsx",sheet_name="GFP_params")
analysis_k4 = pd.read_excel("FCSdaten/20181030-141041_eGFP_20180904_K4_K4.xlsx",sheet_name="GFP_params")
analysis_k5 = pd.read_excel("FCSdaten/20181030-141042_eGFP_20180904_K5_K5.xlsx",sheet_name="GFP_params")
analysis_k6 = pd.read_excel("FCSdaten/20181030-141043_eGFP_20180904_K6_K6.xlsx",sheet_name="GFP_params")

# %%
plt.scatter(analysis_k1['t0']-1,analysis_k1['ktl'])
print(pearsonr(analysis_k1['t0']-1,analysis_k1['ktl']))
# Out:
# (-0.024460056782733625, 0.5921699750915892)

# %%
plt.scatter(analysis_k2['t0']-1,analysis_k2['ktl'])
print(pearsonr(analysis_k2['t0']-1,analysis_k2['ktl']))
# Out:
# (-0.20274444591873925, 0.0007360083543403563)

# %%
plt.scatter(analysis_k3['t0']-1,analysis_k3['ktl'])
print(pearsonr(analysis_k3['t0']-1,analysis_k3['ktl']))
# Out:
# (-0.18405465555784467, 0.005409883763095467)

# %%
plt.scatter(analysis_k4['t0']-1,analysis_k4['ktl'])
print(pearsonr(analysis_k4['t0']-1,analysis_k4['ktl']))
# Out:
# (-0.28023014565606724, 1.2424891220205097e-05)

# %%
plt.scatter(analysis_k5['t0']-1,analysis_k5['ktl'])
print(pearsonr(analysis_k5['t0']-1,analysis_k5['ktl']))
# Out:
# (0.05624177012475758, 0.4520456962976521)

# %%
plt.scatter(analysis_k6['t0']-1,analysis_k6['ktl'])
print(pearsonr(analysis_k6['t0']-1,analysis_k6['ktl']))
# Out:
# (0.024406472336284096, 0.7335312978359048)

# %%
f, axarr = plt.subplots(6, sharex=True,figsize=(6,9))
axarr[0].set_title('t0 histograms')
axarr[0].hist(analysis_k1['t0']-1,bins=30,density=True,label="k1",color='k')
axarr[0].legend()
axarr[1].hist(analysis_k2['t0']-1,bins=30,density=True,label="k2",color='b')
axarr[1].legend()
axarr[2].hist(analysis_k3['t0']-1,bins=30,density=True,label="k3",color='r')
axarr[2].legend()
axarr[3].hist(analysis_k4['t0']-1,bins=30,density=True,label="k4",color='y')
axarr[3].legend()
axarr[4].hist(analysis_k5['t0']-1,bins=30,density=True,label="k5",color='g')
axarr[4].legend()
axarr[5].hist(analysis_k6['t0']-1,bins=30,density=True,label="k6",color='c')
axarr[5].legend()
plt.xlim((0,10))
# Out:
# (0, 10)

# %%
plt.scatter(analysis_k1['t0']-1,analysis_k1['ktl'])
plt.scatter(analysis_k2['t0']-1,analysis_k2['ktl'])
plt.scatter(analysis_k3['t0']-1,analysis_k3['ktl'])
plt.scatter(analysis_k4['t0']-1,analysis_k4['ktl'])
plt.scatter(analysis_k5['t0']-1,analysis_k5['ktl'])
plt.scatter(analysis_k6['t0']-1,analysis_k6['ktl'])

# %%
f, axarr = plt.subplots(6, sharex=True,figsize=(6,9))
axarr[0].set_title('t0 histograms')
axarr[0].hist(analysis_k1['ktl'],bins=30,density=True,label="k1",color='k')
axarr[0].legend()
axarr[1].hist(analysis_k2['ktl'],bins=30,density=True,label="k2",color='b')
axarr[1].legend()
axarr[2].hist(analysis_k3['ktl'],bins=30,density=True,label="k3",color='r')
axarr[2].legend()
axarr[3].hist(analysis_k4['ktl'],bins=30,density=True,label="k4",color='y')
axarr[3].legend()
axarr[4].hist(analysis_k5['ktl'],bins=30,density=True,label="k5",color='g')
axarr[4].legend()
axarr[5].hist(analysis_k6['ktl'],bins=30,density=True,label="k6",color='c')
axarr[5].legend()
plt.xlim((0,1000))
# Out:
# (0, 1000)
